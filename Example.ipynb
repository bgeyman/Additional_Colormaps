# %% [markdown]
# _____________
# **Description**: this script provides example calls for the functions defined in `Additional_Colormaps.py`
# _____________

# %%
# load all functions from Additional_Colormaps
from Additional_Colormaps import *

# %% [markdown]
# _____________
# Load pre-defined cmaps into a single dictionary. Dictionary returned by `load_all_cmaps()` contains *values* of matplotlib ListedColormap objects and *keys* with the cmap names.

# %%
new_cmaps = load_all_cmaps()
new_cmaps
# Out:
# {'ndvi': <matplotlib.colors.ListedColormap at 0x7fd620a5eac0>,
#  'WBGYR': <matplotlib.colors.ListedColormap at 0x7fd6007fea30>,
#  'BGYORV': <matplotlib.colors.ListedColormap at 0x7fd5c0150910>,
#  'precip3_16lev': <matplotlib.colors.ListedColormap at 0x7fd610f83a30>,
#  'perc2_9lev': <matplotlib.colors.ListedColormap at 0x7fd5d8ace310>,
#  'wind_17lev': <matplotlib.colors.ListedColormap at 0x7fd620a8e280>,
#  'cmocean_curl': <matplotlib.colors.ListedColormap at 0x7fd5d8ace550>,
#  'cmocean_ice': <matplotlib.colors.ListedColormap at 0x7fd5d8ace280>,
#  'cmocean_thermal': <matplotlib.colors.ListedColormap at 0x7fd5d8ace220>,
#  'USGS_rainbow': <matplotlib.colors.ListedColormap at 0x7fd5d8ace400>,
#  'USGS_rainbow_15lev_a': <matplotlib.colors.ListedColormap at 0x7fd620a8e310>,
#  'USGS_rainbow_15lev_b': <matplotlib.colors.ListedColormap at 0x7fd620a8e160>,
#  'USGS_rainbow_16lev': <matplotlib.colors.ListedColormap at 0x7fd620a8e5b0>,
#  'rafaj_AQ': <matplotlib.colors.ListedColormap at 0x7fd620a8e2e0>}

# %% [markdown]
# _____________
# Call plot_cmap_example() with one of the pre-defined cmaps loaded in the previous cell

# %%
plot_cmap_example(new_cmaps['rafaj_AQ'])

# %% [markdown]
# _____________
# Get hex color from a list of rgb values using `get_hex_color()`

# %%
test_red = get_hex_color(rgb_code=[196,38,44])
test_blue = get_hex_color(rgb_code=[40,65,122])

plt.plot([0,1], [0,1], c=test_red, lw=20);
plt.plot([0.5,1], [0,0.5], c=test_blue, lw=20);

# %% [markdown]
# _____________
# Make a list of hex codes using `make_hex_list()` and then create custom 256 color **LinearSegmentedColormap** object using `make_custom_cmap_from_hex_list()`

# %%
rgb_list = [[175,162,116], [30,72,105]]
test_hex_list = make_hex_list(rgb_list)
make_custom_cmap_from_hex_list(hex_list=test_hex_list, n_colors=256, cmap_name='test')
